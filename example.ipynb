# %%
from Unity import DataClean
import pandas as pd

# %%
df = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')

# %%
eng = DataClean(df)
eng.data_validator()
# Out:
# Basic Dataset Information:
# --------------------------
# Dataset Shape: (374, 13)
#
# Data Types:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object
#
# First few rows of data:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# ...

# %%
eng.missing_data_handler()
# Out:
# Detailed Missing Data Report by Column:
#                          Missing Count  Percent Missing Data Type
# Sleep Disorder                     219         58.55615    object
# Person ID                            0          0.00000     int64
# Gender                               0          0.00000    object
# Age                                  0          0.00000     int64
# Occupation                           0          0.00000    object
# Sleep Duration                       0          0.00000   float64
# Quality of Sleep                     0          0.00000     int64
# Physical Activity Level              0          0.00000     int64
# Stress Level                         0          0.00000     int64
# BMI Category                         0          0.00000    object
# Blood Pressure                       0          0.00000    object
# Heart Rate                           0          0.00000     int64
# Daily Steps                          0          0.00000     int64
# ...
